# %%
import pandas as pd
df = pd.read_csv("Campaign_Finance_20260206.csv")
df
# Out:
#            ID  Record ID  Report ID  \
# 0     FR12999       2999       2999
# 1     FR12983       2983       2983
# 2     FR12993       2993       2993
# 3     FR12996       2996       2996
# 4     FR12991       2991       2991
# ...       ...        ...        ...
# 1448   F48702      48702       2939
# 1449   F48804      48804       2948
# 1450   F48805      48805       2948
# 1451   F48802      48802       2948
# 1452   F48701      48701       2939
#
#                                               File Link First Name Last Name  \
# 0     https://campfin.dallascityhall.com/FinalReport...      Zarin    Gracey
# 1     https://campfin.dallascityhall.com/FinalReport...        Gay    Willis
# 2     https://campfin.dallascityhall.com/FinalReport...      Laura    Cadena
# 3     https://campfin.dallascityhall.com/FinalReport...       Adam  Bazaldua
# 4     https://campfin.dallascityhall.com/FinalReport...      Lorie     Blair
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1453 non-null   object
#  1   Record ID         1453 non-null   int64
#  2   Report ID         1453 non-null   int64
#  3   File Link         1453 non-null   object
#  4   First Name        687 non-null    object
#  5   Last Name         686 non-null    object
#  6   Business Name     771 non-null    object
#  7   Contact Type      1453 non-null   object
#  8   Record Type       1453 non-null   object
#  9   Amount            1453 non-null   float64
#  10  Schedule Type     1453 non-null   object
#  11  Candidate Name    1453 non-null   object
#  12  Election Date     1325 non-null   object
#  13  Transaction Date  1453 non-null   object
#  14  Street            1453 non-null   object
#  15  City              1453 non-null   object
# ...

# %%
df['Contact Type'].value_counts()
# Out:
# Contact Type
# Expenditure              734
# Contributor              630
# Report Itself             60
# Candidate / Committee     25
# Lender                     4
# Name: count, dtype: int64

# %%
## looking at biggest expenses

# %%
expenses = df[df['Contact Type'] == 'Expenditure']
expenses.groupby('Business Name')['Amount'].sum().sort_values(ascending=False).reset_index().head(20)
# Out:
#                   Business Name     Amount
# 0   CATALYST ADVISORS GROUP LLC  275290.19
# 1           Graphics Management   67182.14
# 2              Adept Strategies   35434.99
# 3                 Printed Union   31125.81
# 4              J.V. Enterprises   15000.00
# 5   Catalyst Advisors Group LLC   11984.04
# 6                   US Treasury   10620.64
# 7            David de la Fuente   10000.00
# 8       DALLAS COUNTY DEMOCRATS   10000.00
# 9                  Hôtel Swexan    9906.13
# 10       United States Treasury    9906.00
# 11                    Mailchimp    9127.89
# 12                    Mi Cocina    8208.94
# 13                     GDA Wins    7707.93
# 14            Beyond the Slogan    7510.00
# 15       PRIMAL FUNDRAISING LLC    6954.84
# 16                    MailChimp    6875.69
# 17            Coffee House Cafe    5867.09
# 18             Culinary Dropout    5865.61
# 19          Jacob Social Source    5344.49

# %%
coffee = expenses[expenses['Business Name'] == 'Graphics Management']
coffee
# Out:
#           ID  Record ID  Report ID  \
# 419   F49205      49205       2958
# 669   F49207      49207       2958
# 784   F49208      49208       2958
# 905   F49192      49192       2958
# 916   F49210      49210       2958
# 1132  F49212      49212       2958
#
#                                               File Link First Name Last Name  \
# 419   https://campfin.dallascityhall.com/FinalReport...        NaN       NaN
# 669   https://campfin.dallascityhall.com/FinalReport...        NaN       NaN
# 784   https://campfin.dallascityhall.com/FinalReport...        NaN       NaN
# 905   https://campfin.dallascityhall.com/FinalReport...        NaN       NaN
# 916   https://campfin.dallascityhall.com/FinalReport...        NaN       NaN
# 1132  https://campfin.dallascityhall.com/FinalReport...        NaN       NaN
#
#             Business Name Contact Type                Record Type    Amount  \
# 419   Graphics Management  Expenditure  July 15: Semi-Annual 2025   1060.92
# ...
