# %% [markdown]
# ## Scraping grand jury cases for Dallas County, Texas, from the [Public Information Act database](https://www.dallascounty.org/dcpia/search):
#  - Since I've found a structured URL, I'm going to create a time range that my script will loop through to get the URLs for all months we want (January 2023-December 2025)
# - Example URL: foiaCSVDetailGJ.jsp?from=2026-02-01&amp;to=2026-03-01&amp;rpt=1
# - The code blocks below will make the base URL loop through our date range to create URLs for each

# %%
#imports
import requests
import pandas as pd
from pathlib import Path

# %%
base_url = "foiaCSVDetailGJ.jsp"
urls = []
year = 2023
month = 1

while (year, month) <= (2025, 12):
    from_date = f"{year}-{month:02d}-01" #ensuring January URL says "01" instead of "1"

    if month == 12:
        to_date = f"{year + 1}-01-01" 
    else:
        to_date = f"{year}-{month + 1:02d}-01" #same logic here

    url = f"{base_url}?from={from_date}&to={to_date}&rpt=1"
    urls.append(url)

    month += 1
    if month == 13:
        month = 1
        year += 1
urls
# Out:
# ['foiaCSVDetailGJ.jsp?from=2023-01-01&to=2023-02-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-02-01&to=2023-03-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-03-01&to=2023-04-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-04-01&to=2023-05-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-05-01&to=2023-06-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-06-01&to=2023-07-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-07-01&to=2023-08-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-08-01&to=2023-09-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-09-01&to=2023-10-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-10-01&to=2023-11-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-11-01&to=2023-12-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2023-12-01&to=2024-01-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-01-01&to=2024-02-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-02-01&to=2024-03-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-03-01&to=2024-04-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-04-01&to=2024-05-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-05-01&to=2024-06-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-06-01&to=2024-07-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-07-01&to=2024-08-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-08-01&to=2024-09-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-09-01&to=2024-10-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-10-01&to=2024-11-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-11-01&to=2024-12-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2024-12-01&to=2025-01-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-01-01&to=2025-02-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-02-01&to=2025-03-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-03-01&to=2025-04-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-04-01&to=2025-05-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-05-01&to=2025-06-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-06-01&to=2025-07-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-07-01&to=2025-08-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-08-01&to=2025-09-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-09-01&to=2025-10-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-10-01&to=2025-11-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-11-01&to=2025-12-01&rpt=1',
#  'foiaCSVDetailGJ.jsp?from=2025-12-01&to=2026-01-01&rpt=1']

# %% [markdown]
# ### Verfying I have 36 urls for 3 years

# %%
len(urls)
# Out:
# 36

# %% [markdown]
# ### Constructing a full URL, saving it to a local folder that I will input back to concat with pandas

# %%
for url in urls:
    full_url = "https://www.dallascounty.org/dcpia/" + url #constructing the full URL
    current_date = url.split("from=")[1].split("&")[0] #getting the "from" part to name the csvs accordingly
    r = requests.get(full_url, timeout=30)
    filename = f"grand_jury_{current_date}.csv"
    filepath = f"grand_jury_files/{filename}" # folder I created in this directory

    with open(filepath, "wb") as f:
        f.write(r.content)

    print(f"Saved {filename}")
# Out:
# Saved grand_jury_2023-01-01.csv
# Saved grand_jury_2023-02-01.csv
# Saved grand_jury_2023-03-01.csv
# Saved grand_jury_2023-04-01.csv
# Saved grand_jury_2023-05-01.csv
# Saved grand_jury_2023-06-01.csv
# Saved grand_jury_2023-07-01.csv
# Saved grand_jury_2023-08-01.csv
# Saved grand_jury_2023-09-01.csv
# Saved grand_jury_2023-10-01.csv
# Saved grand_jury_2023-11-01.csv
# Saved grand_jury_2023-12-01.csv
# Saved grand_jury_2024-01-01.csv
# Saved grand_jury_2024-02-01.csv
# Saved grand_jury_2024-03-01.csv
# Saved grand_jury_2024-04-01.csv
# Saved grand_jury_2024-05-01.csv
# Saved grand_jury_2024-06-01.csv
# Saved grand_jury_2024-07-01.csv
# Saved grand_jury_2024-08-01.csv
# Saved grand_jury_2024-09-01.csv
# Saved grand_jury_2024-10-01.csv
# Saved grand_jury_2024-11-01.csv
# Saved grand_jury_2024-12-01.csv
# Saved grand_jury_2025-01-01.csv
# Saved grand_jury_2025-02-01.csv
# Saved grand_jury_2025-03-01.csv
# Saved grand_jury_2025-04-01.csv
# Saved grand_jury_2025-05-01.csv
# Saved grand_jury_2025-06-01.csv
# Saved grand_jury_2025-07-01.csv
# Saved grand_jury_2025-08-01.csv
# Saved grand_jury_2025-09-01.csv
# Saved grand_jury_2025-10-01.csv
# Saved grand_jury_2025-11-01.csv
# Saved grand_jury_2025-12-01.csv

# %%
data = Path("grand_jury_files")
dfs = [
    pd.read_csv(csv)
    for csv in sorted(data.glob("*.csv"))
]
df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ### Some sanity checks, sorting the df and seeing if the first and last few rows from here match the database

# %%
df.sort_values(by=['GJ Disposition Date', 'Defendant Name']) 
df
# Out:
#                Defendant Name                                        Address  \
# 0         ALVAREZ JOSHUA LUKE   345 IDAHO ST COLORADO SPRINGS Colorado 80452
# 1          BALDERRAMA DANIEL               7303 REDBUD DR DALLAS Texas 75227
# 2      BARRERA JOSSUE EDGARDO        2712 N BUCKNER BLVD  DALLAS Texas 75228
# 3       BASTAKOTI PREM PRASAD      2017 DELTA DOWNS  SEAGOVILLE  Texas 75159
# 4        CASTON RINWICK LAVON          3501 N BUCKNER BLD DALLAS Texas 75228
# ...                       ...                                            ...
# 74572   YOUMAN SHANNON YVONNE  4848 ELSIE FAYE HEGGINS ST DALLAS Texas 75210
# 74573           ZUBIRI ISAAC            3231 URBAN AVENUE DALLAS Texas 75227
# 74574           ZUBIRI ISAAC                 3231 URBAN AVENUE DALLAS  75227
# 74575      ZUBIRI JAMIE PEREZ                3115 RUTZ ST DALLAS Texas 75212
# 74576      ZUBIRI JAMIE PEREZ                3115 RUTZ ST DALLAS Texas 75212
#
#       Case Number                                     Offense Offense Date  \
# 0        F2255138                        BURGLARY OF BUILDING   2022-06-04
# 1        F1875824                        BURGLARY OF BUILDING   2018-05-08
# 2        F2260498                 AGG ASSAULT W/DEADLY WEAPON   2022-12-06
# 3        M2303802  ASSAULT CAUSES BODILY INJURY FAMILY MEMBER   2022-12-07
# 4        F2260460                 ASSAULT PEACE OFFICER/JUDGE   2022-12-05
# ...           ...                                         ...          ...
# 74572    F2560669          POSS CS PG1/1B <1G DFZ IAT 481.115   2025-11-14
# 74573    F2476803                   MAN DEL CS PG 1 >=4G<200G   2024-05-30
# 74574    F2458589                     MAN/DEL CS PG 1 >= 400G   2024-09-04
# 74575    F2560727                        POSS CS PG 1/1-B <1G   2025-11-15
# 74576    F2560726                        POSS CS PG 1/1-B <1G   2025-11-15
#
#         Defense Attorney GJ Disposition GJ Disposition Date
# 0        Matthew Seymour      True Bill          2023-01-05
# 1                             True Bill          2023-01-05
# 2          Roberto Dueno      True Bill          2023-01-05
# 3           Bruce Patton      True Bill          2023-01-05
# 4        Sherrod Edwards      True Bill          2023-01-05
# ...                  ...            ...                 ...
# 74572  Jennifer Castillo      True Bill          2025-12-29
# 74573      Joshua Webber      True Bill          2025-12-29
# 74574      Joshua Webber      True Bill          2025-12-29
# 74575     Gabriel Ogueri      True Bill          2025-12-29
# 74576     Gabriel Ogueri      True Bill          2025-12-29
#
# [74577 rows x 8 columns]

# %% [markdown]
# ### The first few rows of January 2023 and last few rows of December 2025 are matching the database.
# ### Some more sanity checks, looking at November 2025 file

# %%
df2 = pd.read_csv("grand_jury_files/grand_jury_2025-11-01.csv")
df2
# Out:
#                      Defendant Name  \
# 0                    ALVARADO ERIC
# 1     ARELLANOLOPEZ ALONSO BENJAMIN
# 2                  ASCENCIO MANUEL
# 3                   AVILLA ROMARIO
# 4                      BAKER ODELL
# ...                             ...
# 2052                   WALI ROBERT
# 2053            WHALEN RYAN PATRICK
# 2054          WHITLOCK DAVID RANALE
# 2055          WHITLOCK DAVID RANALE
# 2056           WILSON ASHLEY LESHAY
#
#                                               Address Case Number  \
# 0              7232 ELLIS ROAD FORT WORTH Texas 76112    F2448551
# 1     7010 STAFFORDSHIRE BLVD #44 HOUSTON Texas 77030    F2471554
# 2                     6450 SO SECO DALLAS Texas 75217    F2532462
# 3                                                        F2525682
# 4                                         HOMELESS       F2525727
# ...                                               ...         ...
# 2052   3154 CHRISTOPHER ST GRAND PRAIRIE  Texas 75052    F2531497
# 2053           2502 SERENITY LANE ROWLETT Texas 75088    F2461684
# 2054              2621 ASHGLEN DR GARLAND Texas 75043    F2525531
# 2055           2613 ASHGLEN DRIVE GARLAND Texas 75043    F2540593
# 2056      13920 MANDOLIN DR #2212 HOUSTON Texas 77070    F2541513
#
#                                         Offense Offense Date  \
# 0     DRIVING WHILE INTOXICATED 3RD OR MORE IAT   2024-12-21
# 1                          SEXUAL ASSAULT CHILD   2024-02-09
# 2     DRIVING WHILE INTOXICATED 3RD OR MORE IAT   2025-01-03
# 3                          POSS CS PG 1/1-B <1G   2025-09-18
# 4                          POSS CS PG 1/1-B <1G   2025-09-22
# ...                                         ...          ...
# 2052                       POSS CS PG 1/1-B <1G   2025-10-05
# 2053                AGG ASSAULT W/DEADLY WEAPON   2024-12-23
# 2054                MAN DEL CS PG 1-B >=4G<200G   2025-08-28
# 2055                 POSS CS PG 1/1-B >=4G<200G   2025-03-14
# 2056                AGG ASSAULT W/DEADLY WEAPON   2025-07-08
#
#        Defense Attorney GJ Disposition GJ Disposition Date
# 0            John Avery      True Bill          2025-11-03
# 1                            True Bill          2025-11-03
# 2         MOSES BRISENO      True Bill          2025-11-03
# 3          Craig Stango      True Bill          2025-11-03
# 4             carl hays      True Bill          2025-11-03
# ...                 ...            ...                 ...
# 2052                         True Bill          2025-12-01
# 2053     Maria Costilla      True Bill          2025-12-01
# 2054       Leigh DeMasi      True Bill          2025-12-01
# 2055       Leigh DeMasi      True Bill          2025-12-01
# 2056  Tulani Washington      True Bill          2025-12-01
#
# [2057 rows x 8 columns]

# %% [markdown]
# ### This looks fine too, checking if there are any duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(1420)

# %% [markdown]
# #### Inspecting duplicates

# %%
duplicates = df[df.duplicated(keep=False)].sort_values(by=list(df.columns))
duplicates
# Out:
#            Defendant Name                                        Address  \
# 14904        AARON DONTA           3811 E KIEST BLVD  DALLAS Texas 75203
# 15037        AARON DONTA           3811 E KIEST BLVD  DALLAS Texas 75203
# 9033   ABED MUSSIE ABRAHA          3205 ROUNDTREE LN GARLAND Texas 75044
# 9187   ABED MUSSIE ABRAHA          3205 ROUNDTREE LN GARLAND Texas 75044
# 72462   ACCAAL SEBASTIAN         3233 NORWALK AVE 106 DALLAS Texas 75220
# ...                   ...                                            ...
# 11751   ZUNIGA CHRISTIAN   1629 CLIFTON COURT  GRAND PRAIRIE Texas 75051
# 11663   ZUNIGA CHRISTIAN   1629 CLIFTON COURT  GRAND PRAIRIE Texas 75051
# 11749   ZUNIGA CHRISTIAN   1629 CLIFTON COURT  GRAND PRAIRIE Texas 75051
# 11665   ZUNIGA CHRISTIAN    1629 CLIFTON COURT GRAND PRAIRIE Texas 75051
# 11750   ZUNIGA CHRISTIAN    1629 CLIFTON COURT GRAND PRAIRIE Texas 75051
#
#       Case Number                                     Offense Offense Date  \
# 14904    F2355961  AGG ASSAULT DATE/FAMILY/HOUSE SBI W/WEAPON   2023-06-29
# 15037    F2355961  AGG ASSAULT DATE/FAMILY/HOUSE SBI W/WEAPON   2023-06-29
# 9033     F2260702                   SOLICIT PROST/OTHER PAYOR   2022-12-15
# 9187     F2260702                   SOLICIT PROST/OTHER PAYOR   2022-12-15
# 72462    F2557161                 AGG ASSAULT W/DEADLY WEAPON   2025-07-27
# ...           ...                                         ...          ...
# 11751    F2330600                                 AGG ROBBERY   2023-04-18
# 11663    F2330614                                 AGG ROBBERY   2023-04-18
# 11749    F2330614                                 AGG ROBBERY   2023-04-18
# 11665    F2330599                                 AGG ROBBERY   2023-04-18
# 11750    F2330599                                 AGG ROBBERY   2023-04-18
#
#       Defense Attorney GJ Disposition GJ Disposition Date
# 14904   Matthew Arnold      True Bill          2023-08-01
# 15037   Matthew Arnold      True Bill          2023-08-01
# 9033       Bruce Anton      True Bill          2023-05-01
# 9187       Bruce Anton      True Bill          2023-05-01
# 72462    Laura Andrade      True Bill          2025-12-01
# ...                ...            ...                 ...
# 11751     Elaine Evans      True Bill          2023-06-01
# 11663     Elaine Evans      True Bill          2023-06-01
# 11749     Elaine Evans      True Bill          2023-06-01
# 11665     Elaine Evans      True Bill          2023-06-01
# 11750     Elaine Evans      True Bill          2023-06-01
#
# [2840 rows x 8 columns]

# %% [markdown]
# ### Aah, I know what's happening:
# This has to do with how they're the files are structured. We already saw that the end date of a month is actually the start date of the second month. For example, the file for January 2023 ends on February 1, 2023. So some cases on the first of any month will overlap across two CSVs. The easy fix is to remove any rows with duplicate Case Numbers.

# %% [markdown]
# ### Okay, I'm fairly confident that after this step, the dataset will be complete and am comfortable handing it over.
# ### Next steps:
# Check a few more files to see if any data is missing, run steps by Data Editor, pass on the final file without duplicates to the reporter.

# %% [markdown]
# ### Future considerations:
# - The advantage of this script is that if a reporter wants data from the same dataset a year later, I can simply expand the range in the first block, run the code again and give them a new database in minutes.
# - It's also better than an automated browser or multi-page scrape since it is less complicated and parsing the data will be much quicker.
# - If the reporter says they want scheduled cases instead of disposed ones (or some other dropdown option), we simply switch the report number in the URL (rpt=1).
